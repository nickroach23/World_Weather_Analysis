# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests 
import random
from citipy import citipy
# Import the ApI key.
from config import weather_api_key
from datetime import datetime
import timeit
import gmaps.datasets
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a lsit 
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 624

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" +weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          })
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | nizwa
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | asosa
# Processing Record 7 of Set 1 | burica
# City not found. Skipping...
# Processing Record 8 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | edson
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | rognan
# Processing Record 14 of Set 1 | bubaque
# Processing Record 15 of Set 1 | palmer
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | dingle
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | turukhansk
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | san quintin
# Processing Record 23 of Set 1 | meybod
# Processing Record 24 of Set 1 | harper
# Processing Record 25 of Set 1 | eureka
# Processing Record 26 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | hami
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | airai
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | narsaq
# Processing Record 43 of Set 1 | north bend
# Processing Record 44 of Set 1 | altay
# Processing Record 45 of Set 1 | jalalabad
# Processing Record 46 of Set 1 | nuuk
# Processing Record 47 of Set 1 | jumla
# Processing Record 48 of Set 1 | gornyak
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | rio grande
# Processing Record 2 of Set 2 | provideniya
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | verkhnyaya inta
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | vysokogornyy
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | tchaourou
# Processing Record 10 of Set 2 | grimshaw
# Processing Record 11 of Set 2 | guia de isora
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | piacenza
# Processing Record 14 of Set 2 | perth
# Processing Record 15 of Set 2 | kenai
# Processing Record 16 of Set 2 | taga
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | ginda
# Processing Record 19 of Set 2 | berbera
# Processing Record 20 of Set 2 | soligalich
# Processing Record 21 of Set 2 | morondava
# Processing Record 22 of Set 2 | gat
# Processing Record 23 of Set 2 | saint-augustin
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | sao paulo de olivenca
# Processing Record 26 of Set 2 | gamba
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | san juan
# Processing Record 29 of Set 2 | broome
# Processing Record 30 of Set 2 | athens
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | gizo
# Processing Record 33 of Set 2 | meulaboh
# Processing Record 34 of Set 2 | cayenne
# Processing Record 35 of Set 2 | port lincoln
# Processing Record 36 of Set 2 | berlevag
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | henties bay
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | sola
# Processing Record 41 of Set 2 | port hueneme
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | acari
# Processing Record 44 of Set 2 | tirunelveli
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | songea
# Processing Record 47 of Set 2 | saint-jovite
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | laguna
# Processing Record 50 of Set 2 | pulandian
# Processing Record 1 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 3 | aklavik
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | weston
# Processing Record 5 of Set 3 | ponta delgada
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 3 | ciras
# City not found. Skipping...
# Processing Record 9 of Set 3 | bacalar
# Processing Record 10 of Set 3 | kavaratti
# Processing Record 11 of Set 3 | karratha
# Processing Record 12 of Set 3 | ahipara
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | coquimbo
# Processing Record 16 of Set 3 | portland
# Processing Record 17 of Set 3 | jega
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | ushuaia
# Processing Record 21 of Set 3 | dargaville
# Processing Record 22 of Set 3 | ust-maya
# Processing Record 23 of Set 3 | karpathos
# Processing Record 24 of Set 3 | dunedin
# Processing Record 25 of Set 3 | benjamin hill
# Processing Record 26 of Set 3 | krasnoye
# Processing Record 27 of Set 3 | dauphin
# Processing Record 28 of Set 3 | aksu
# Processing Record 29 of Set 3 | awjilah
# Processing Record 30 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 3 | sawakin
# Processing Record 32 of Set 3 | bilibino
# Processing Record 33 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | alofi
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | kloulklubed
# Processing Record 38 of Set 3 | severo-kurilsk
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | moyale
# Processing Record 41 of Set 3 | wenling
# Processing Record 42 of Set 3 | batamshinskiy
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 3 | tezu
# Processing Record 46 of Set 3 | sladkovicovo
# Processing Record 47 of Set 3 | chokurdakh
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | ponta do sol
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | schio
# Processing Record 2 of Set 4 | sayville
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | dwarka
# Processing Record 5 of Set 4 | bathsheba
# Processing Record 6 of Set 4 | brae
# Processing Record 7 of Set 4 | sirjan
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | waitati
# Processing Record 13 of Set 4 | ostrovnoy
# Processing Record 14 of Set 4 | syedove
# Processing Record 15 of Set 4 | tsaratanana
# Processing Record 16 of Set 4 | namibe
# Processing Record 17 of Set 4 | limenaria
# Processing Record 18 of Set 4 | port hedland
# Processing Record 19 of Set 4 | saint stephen
# Processing Record 20 of Set 4 | boyolangu
# Processing Record 21 of Set 4 | durusu
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | gornozavodsk
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | burnie
# Processing Record 26 of Set 4 | mossendjo
# Processing Record 27 of Set 4 | arraial do cabo
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | lomianki
# Processing Record 30 of Set 4 | banda aceh
# Processing Record 31 of Set 4 | dudinka
# Processing Record 32 of Set 4 | tual
# Processing Record 33 of Set 4 | yellowknife
# Processing Record 34 of Set 4 | lagoa
# Processing Record 35 of Set 4 | labuhan
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | strai
# Processing Record 39 of Set 4 | constitucion
# Processing Record 40 of Set 4 | hornepayne
# Processing Record 41 of Set 4 | lazarev
# Processing Record 42 of Set 4 | jibuti
# Processing Record 43 of Set 4 | bayji
# Processing Record 44 of Set 4 | sao joao da barra
# Processing Record 45 of Set 4 | qaanaaq
# Processing Record 46 of Set 4 | acapulco
# Processing Record 47 of Set 4 | basco
# Processing Record 48 of Set 4 | wanning
# Processing Record 49 of Set 4 | saint anthony
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | zheleznodorozhnyy
# Processing Record 2 of Set 5 | moerai
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | thinadhoo
# Processing Record 5 of Set 5 | avera
# Processing Record 6 of Set 5 | price
# Processing Record 7 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 5 | pingliang
# Processing Record 9 of Set 5 | sebinkarahisar
# Processing Record 10 of Set 5 | flinders
# Processing Record 11 of Set 5 | tahta
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | chirongui
# Processing Record 14 of Set 5 | shitanjing
# Processing Record 15 of Set 5 | samarai
# Processing Record 16 of Set 5 | mackenzie
# Processing Record 17 of Set 5 | arcata
# Processing Record 18 of Set 5 | itarema
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | port elizabeth
# Processing Record 21 of Set 5 | najran
# Processing Record 22 of Set 5 | charters towers
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | omutninsk
# Processing Record 25 of Set 5 | namatanai
# Processing Record 26 of Set 5 | cabedelo
# Processing Record 27 of Set 5 | pisco
# Processing Record 28 of Set 5 | tuim
# Processing Record 29 of Set 5 | shintomi
# Processing Record 30 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | ballina
# Processing Record 33 of Set 5 | nhulunbuy
# Processing Record 34 of Set 5 | pacific grove
# Processing Record 35 of Set 5 | upernavik
# Processing Record 36 of Set 5 | leningradskiy
# Processing Record 37 of Set 5 | porto novo
# Processing Record 38 of Set 5 | loding
# Processing Record 39 of Set 5 | pandamatenga
# Processing Record 40 of Set 5 | abbeville
# Processing Record 41 of Set 5 | noyabrsk
# Processing Record 42 of Set 5 | sistranda
# Processing Record 43 of Set 5 | kyrylivka
# Processing Record 44 of Set 5 | okha
# Processing Record 45 of Set 5 | saint george
# Processing Record 46 of Set 5 | cabo san lucas
# Processing Record 47 of Set 5 | kjollefjord
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | guebwiller
# Processing Record 1 of Set 6 | lemon tree passage
# Processing Record 2 of Set 6 | balad
# Processing Record 3 of Set 6 | las guacamayas
# Processing Record 4 of Set 6 | mayna
# Processing Record 5 of Set 6 | mount isa
# Processing Record 6 of Set 6 | butembo
# Processing Record 7 of Set 6 | shimanovsk
# Processing Record 8 of Set 6 | chapais
# Processing Record 9 of Set 6 | tilichiki
# Processing Record 10 of Set 6 | boralday
# Processing Record 11 of Set 6 | karagaylinskiy
# Processing Record 12 of Set 6 | hamilton
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | popondetta
# Processing Record 15 of Set 6 | betsiamites
# Processing Record 16 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 6 | carutapera
# Processing Record 18 of Set 6 | visby
# Processing Record 19 of Set 6 | abha
# Processing Record 20 of Set 6 | aldan
# Processing Record 21 of Set 6 | maniitsoq
# Processing Record 22 of Set 6 | ilirska bistrica
# Processing Record 23 of Set 6 | uetze
# Processing Record 24 of Set 6 | nouadhibou
# Processing Record 25 of Set 6 | buchanan
# Processing Record 26 of Set 6 | fort beaufort
# Processing Record 27 of Set 6 | bure
# Processing Record 28 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 6 | east london
# Processing Record 30 of Set 6 | lev tolstoy
# Processing Record 31 of Set 6 | suao
# City not found. Skipping...
# Processing Record 32 of Set 6 | lincoln
# Processing Record 33 of Set 6 | coihaique
# Processing Record 34 of Set 6 | lagos
# Processing Record 35 of Set 6 | sakakah
# Processing Record 36 of Set 6 | sinnamary
# Processing Record 37 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 6 | kultuk
# Processing Record 39 of Set 6 | laela
# Processing Record 40 of Set 6 | kijang
# Processing Record 41 of Set 6 | parambu
# Processing Record 42 of Set 6 | vostok
# Processing Record 43 of Set 6 | vardo
# Processing Record 44 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 6 | hadgaon
# Processing Record 46 of Set 6 | norman wells
# Processing Record 47 of Set 6 | torbay
# Processing Record 48 of Set 6 | roblin
# Processing Record 49 of Set 6 | vanimo
# Processing Record 50 of Set 6 | ahmadpur
# Processing Record 1 of Set 7 | fukue
# Processing Record 2 of Set 7 | hay river
# Processing Record 3 of Set 7 | carballo
# Processing Record 4 of Set 7 | magistralnyy
# Processing Record 5 of Set 7 | krasnyy luch
# Processing Record 6 of Set 7 | kristiansund
# Processing Record 7 of Set 7 | chapadinha
# Processing Record 8 of Set 7 | malindi
# Processing Record 9 of Set 7 | caloundra
# Processing Record 10 of Set 7 | kostomuksha
# Processing Record 11 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 12 of Set 7 | bima
# Processing Record 13 of Set 7 | muros
# Processing Record 14 of Set 7 | kupang
# Processing Record 15 of Set 7 | prince albert
# Processing Record 16 of Set 7 | sortavala
# Processing Record 17 of Set 7 | isangel
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | atoka
# Processing Record 21 of Set 7 | tuatapere
# Processing Record 22 of Set 7 | asuncion nochixtlan
# Processing Record 23 of Set 7 | arman
# Processing Record 24 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 7 | mehamn
# Processing Record 26 of Set 7 | linqu
# Processing Record 27 of Set 7 | mandalgovi
# Processing Record 28 of Set 7 | guerrero negro
# Processing Record 29 of Set 7 | ohara
# Processing Record 30 of Set 7 | tautira
# Processing Record 31 of Set 7 | aasiaat
# Processing Record 32 of Set 7 | kasongo-lunda
# Processing Record 33 of Set 7 | bereda
# Processing Record 34 of Set 7 | dubbo
# Processing Record 35 of Set 7 | oistins
# Processing Record 36 of Set 7 | kathmandu
# Processing Record 37 of Set 7 | ridgecrest
# Processing Record 38 of Set 7 | orodara
# Processing Record 39 of Set 7 | high rock
# Processing Record 40 of Set 7 | port shepstone
# Processing Record 41 of Set 7 | muriae
# Processing Record 42 of Set 7 | nemuro
# Processing Record 43 of Set 7 | xuddur
# Processing Record 44 of Set 7 | ankpa
# Processing Record 45 of Set 7 | lakes entrance
# Processing Record 46 of Set 7 | virginia beach
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | kaeo
# Processing Record 49 of Set 7 | lerwick
# Processing Record 50 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 8 | baiyin
# Processing Record 2 of Set 8 | antofagasta
# Processing Record 3 of Set 8 | issoire
# Processing Record 4 of Set 8 | bilma
# Processing Record 5 of Set 8 | acajutla
# Processing Record 6 of Set 8 | nimaparha
# Processing Record 7 of Set 8 | cherskiy
# Processing Record 8 of Set 8 | waingapu
# Processing Record 9 of Set 8 | nanortalik
# Processing Record 10 of Set 8 | santa fe
# Processing Record 11 of Set 8 | talcahuano
# Processing Record 12 of Set 8 | christchurch
# Processing Record 13 of Set 8 | kedrovyy
# Processing Record 14 of Set 8 | turayf
# Processing Record 15 of Set 8 | middelburg
# Processing Record 16 of Set 8 | visnes
# Processing Record 17 of Set 8 | piedras negras
# Processing Record 18 of Set 8 | grindavik
# Processing Record 19 of Set 8 | kununurra
# Processing Record 20 of Set 8 | kahului
# Processing Record 21 of Set 8 | superior
# Processing Record 22 of Set 8 | necochea
# Processing Record 23 of Set 8 | kudat
# Processing Record 24 of Set 8 | ongandjera
# Processing Record 25 of Set 8 | corrente
# Processing Record 26 of Set 8 | ranong
# Processing Record 27 of Set 8 | trenggalek
# Processing Record 28 of Set 8 | elat
# Processing Record 29 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 8 | prior lake
# Processing Record 31 of Set 8 | abancay
# Processing Record 32 of Set 8 | sidney
# Processing Record 33 of Set 8 | uvalde
# Processing Record 34 of Set 8 | pemba
# Processing Record 35 of Set 8 | cidreira
# Processing Record 36 of Set 8 | cairns
# Processing Record 37 of Set 8 | faanui
# Processing Record 38 of Set 8 | baruun-urt
# Processing Record 39 of Set 8 | sonoita
# Processing Record 40 of Set 8 | volksrust
# Processing Record 41 of Set 8 | ouadda
# Processing Record 42 of Set 8 | santa maria
# Processing Record 43 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 8 | macomb
# Processing Record 45 of Set 8 | makinsk
# Processing Record 46 of Set 8 | lavrentiya
# Processing Record 47 of Set 8 | elko
# Processing Record 48 of Set 8 | kokstad
# Processing Record 49 of Set 8 | piacabucu
# Processing Record 50 of Set 8 | avesta
# Processing Record 1 of Set 9 | shar
# Processing Record 2 of Set 9 | terny
# Processing Record 3 of Set 9 | santa rita
# Processing Record 4 of Set 9 | plunge
# Processing Record 5 of Set 9 | wad rawah
# Processing Record 6 of Set 9 | ilan
# Processing Record 7 of Set 9 | podor
# Processing Record 8 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 9 | richards bay
# Processing Record 10 of Set 9 | santa rosa
# Processing Record 11 of Set 9 | sabha
# Processing Record 12 of Set 9 | yatou
# Processing Record 13 of Set 9 | san isidro
# Processing Record 14 of Set 9 | mbaiki
# Processing Record 15 of Set 9 | tessalit
# Processing Record 16 of Set 9 | jacareacanga
# Processing Record 17 of Set 9 | shieli
# Processing Record 18 of Set 9 | olafsvik
# Processing Record 19 of Set 9 | carberry
# Processing Record 20 of Set 9 | matay
# Processing Record 21 of Set 9 | safford
# Processing Record 22 of Set 9 | san andres
# Processing Record 23 of Set 9 | kyaikkami
# Processing Record 24 of Set 9 | cauquenes
# Processing Record 25 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 9 | hailey
# Processing Record 27 of Set 9 | nakhon phanom
# Processing Record 28 of Set 9 | balykshi
# Processing Record 29 of Set 9 | high level
# Processing Record 30 of Set 9 | tenextatiloyan
# City not found. Skipping...
# Processing Record 31 of Set 9 | yining
# Processing Record 32 of Set 9 | mezen
# Processing Record 33 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 9 | keti bandar
# Processing Record 35 of Set 9 | straldza
# City not found. Skipping...
# Processing Record 36 of Set 9 | houma
# Processing Record 37 of Set 9 | goderich
# Processing Record 38 of Set 9 | mahibadhoo
# Processing Record 39 of Set 9 | paamiut
# Processing Record 40 of Set 9 | kulhudhuffushi
# Processing Record 41 of Set 9 | urubicha
# Processing Record 42 of Set 9 | alice springs
# Processing Record 43 of Set 9 | nenjiang
# Processing Record 44 of Set 9 | kharp
# Processing Record 45 of Set 9 | imeni poliny osipenko
# Processing Record 46 of Set 9 | poum
# Processing Record 47 of Set 9 | pflugerville
# Processing Record 48 of Set 9 | oudtshoorn
# Processing Record 49 of Set 9 | ustynivka
# Processing Record 50 of Set 9 | bandarbeyla
# Processing Record 1 of Set 10 | saraza
# Processing Record 2 of Set 10 | huescar
# Processing Record 3 of Set 10 | verkhnevilyuysk
# Processing Record 4 of Set 10 | skwierzyna
# Processing Record 5 of Set 10 | mago
# Processing Record 6 of Set 10 | rio gallegos
# Processing Record 7 of Set 10 | ngudu
# Processing Record 8 of Set 10 | sydney
# Processing Record 9 of Set 10 | escanaba
# Processing Record 10 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 10 | talnakh
# Processing Record 12 of Set 10 | sambava
# Processing Record 13 of Set 10 | salalah
# Processing Record 14 of Set 10 | tambura
# Processing Record 15 of Set 10 | blagoyevo
# Processing Record 16 of Set 10 | yeppoon
# Processing Record 17 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 10 | gander
# Processing Record 19 of Set 10 | saldanha
# Processing Record 20 of Set 10 | san luis
# Processing Record 21 of Set 10 | phan thiet
# Processing Record 22 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 10 | marang
# Processing Record 24 of Set 10 | northport
# Processing Record 25 of Set 10 | fujin
# Processing Record 26 of Set 10 | ampanihy
# Processing Record 27 of Set 10 | camopi
# Processing Record 28 of Set 10 | nuevitas
# Processing Record 29 of Set 10 | aksarka
# Processing Record 30 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 10 | kalmar
# Processing Record 32 of Set 10 | noumea
# Processing Record 33 of Set 10 | fairbanks
# Processing Record 34 of Set 10 | burayevo
# Processing Record 35 of Set 10 | kruisfontein
# Processing Record 36 of Set 10 | maldonado
# Processing Record 37 of Set 10 | moranbah
# Processing Record 38 of Set 10 | lodeynoye pole
# Processing Record 39 of Set 10 | rosehearty
# Processing Record 40 of Set 10 | pasinler
# Processing Record 41 of Set 10 | fayaoue
# Processing Record 42 of Set 10 | forbes
# Processing Record 43 of Set 10 | chhata
# Processing Record 44 of Set 10 | ormara
# Processing Record 45 of Set 10 | linqiong
# Processing Record 46 of Set 10 | dhuburi
# Processing Record 47 of Set 10 | mocuba
# Processing Record 48 of Set 10 | turka
# Processing Record 49 of Set 10 | inuvik
# Processing Record 50 of Set 10 | mabaruma
# Processing Record 1 of Set 11 | kautokeino
# Processing Record 2 of Set 11 | zhanakorgan
# Processing Record 3 of Set 11 | margate
# Processing Record 4 of Set 11 | oussouye
# Processing Record 5 of Set 11 | lipari
# Processing Record 6 of Set 11 | haines junction
# Processing Record 7 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 11 | nome
# Processing Record 9 of Set 11 | la maddalena
# Processing Record 10 of Set 11 | makakilo city
# Processing Record 11 of Set 11 | matara
# Processing Record 12 of Set 11 | asyut
# Processing Record 13 of Set 11 | walvis bay
# Processing Record 14 of Set 11 | puerto leguizamo
# Processing Record 15 of Set 11 | paramaribo
# Processing Record 16 of Set 11 | luderitz
# Processing Record 17 of Set 11 | hambantota
# Processing Record 18 of Set 11 | calvinia
# Processing Record 19 of Set 11 | anadyr
# Processing Record 20 of Set 11 | kambove
# Processing Record 21 of Set 11 | korla
# Processing Record 22 of Set 11 | hun
# Processing Record 23 of Set 11 | rovira
# Processing Record 24 of Set 11 | butte
# Processing Record 25 of Set 11 | zaraza
# Processing Record 26 of Set 11 | yueyang
# Processing Record 27 of Set 11 | gumdag
# Processing Record 28 of Set 11 | wufeng
# Processing Record 29 of Set 11 | payyannur
# Processing Record 30 of Set 11 | pahrump
# Processing Record 31 of Set 11 | port augusta
# Processing Record 32 of Set 11 | soavinandriana
# Processing Record 33 of Set 11 | bay-khaak
# Processing Record 34 of Set 11 | boden
# Processing Record 35 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 36 of Set 11 | denpasar
# Processing Record 37 of Set 11 | malakal
# Processing Record 38 of Set 11 | valley city
# Processing Record 39 of Set 11 | deogarh
# Processing Record 40 of Set 11 | yanam
# Processing Record 41 of Set 11 | byron bay
# Processing Record 42 of Set 11 | douentza
# Processing Record 43 of Set 11 | ulladulla
# Processing Record 44 of Set 11 | sumenep
# Processing Record 45 of Set 11 | watrous
# Processing Record 46 of Set 11 | kholodnyy
# Processing Record 47 of Set 11 | dingzhou
# Processing Record 48 of Set 11 | shumyachi
# Processing Record 49 of Set 11 | moron
# Processing Record 50 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 12 | seoul
# Processing Record 2 of Set 12 | kargopol
# Processing Record 3 of Set 12 | diamantino
# Processing Record 4 of Set 12 | kudahuvadhoo
# Processing Record 5 of Set 12 | mogadishu
# Processing Record 6 of Set 12 | udachnyy
# Processing Record 7 of Set 12 | krasnoselkup
# Processing Record 8 of Set 12 | pangnirtung
# Processing Record 9 of Set 12 | havre-saint-pierre
# Processing Record 10 of Set 12 | tanout
# Processing Record 11 of Set 12 | yala
# Processing Record 12 of Set 12 | medzev
# Processing Record 13 of Set 12 | klyuchi
# Processing Record 14 of Set 12 | balabac
# Processing Record 15 of Set 12 | marawi
# Processing Record 16 of Set 12 | assiniboia
# Processing Record 17 of Set 12 | bracebridge
# Processing Record 18 of Set 12 | verkhnyaya toyma
# Processing Record 19 of Set 12 | murdochville
# Processing Record 20 of Set 12 | ullal
# Processing Record 21 of Set 12 | ladybrand
# Processing Record 22 of Set 12 | preobrazheniye
# Processing Record 23 of Set 12 | khanpur
# Processing Record 24 of Set 12 | pangody
# Processing Record 25 of Set 12 | kilindoni
# Processing Record 26 of Set 12 | frunze
# Processing Record 27 of Set 12 | arsk
# Processing Record 28 of Set 12 | husavik
# Processing Record 29 of Set 12 | mugur-aksy
# Processing Record 30 of Set 12 | port arthur
# Processing Record 31 of Set 12 | pelym
# Processing Record 32 of Set 12 | collie
# Processing Record 33 of Set 12 | lodja
# Processing Record 34 of Set 12 | charyshskoye
# Processing Record 35 of Set 12 | palana
# Processing Record 36 of Set 12 | filadelfia
# Processing Record 37 of Set 12 | corpus christi
# Processing Record 38 of Set 12 | orange cove
# Processing Record 39 of Set 12 | batagay-alyta
# Processing Record 40 of Set 12 | comodoro rivadavia
# Processing Record 41 of Set 12 | san borja
# Processing Record 42 of Set 12 | amapa
# Processing Record 43 of Set 12 | erzin
# Processing Record 44 of Set 12 | filingue
# Processing Record 45 of Set 12 | lewiston
# Processing Record 46 of Set 12 | shumskiy
# Processing Record 47 of Set 12 | paracuru
# Processing Record 48 of Set 12 | mazagao
# Processing Record 49 of Set 12 | mayo
# Processing Record 50 of Set 12 | ponnani
# Processing Record 1 of Set 13 | bac lieu
# Processing Record 2 of Set 13 | inta
# Processing Record 3 of Set 13 | sharjah
# Processing Record 4 of Set 13 | bell ville
# Processing Record 5 of Set 13 | manokwari
# Processing Record 6 of Set 13 | praia
# Processing Record 7 of Set 13 | tooele
# Processing Record 8 of Set 13 | ravar
# Processing Record 9 of Set 13 | ewa beach
# Processing Record 10 of Set 13 | whitecourt
# Processing Record 11 of Set 13 | salinas
# Processing Record 12 of Set 13 | poykovskiy
# Processing Record 13 of Set 13 | biu
# Processing Record 14 of Set 13 | mitsamiouli
# Processing Record 15 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 16 of Set 13 | meadow lake
# Processing Record 17 of Set 13 | shache
# Processing Record 18 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 19 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 20 of Set 13 | bratsk
# Processing Record 21 of Set 13 | pacifica
# Processing Record 22 of Set 13 | ucluelet
# Processing Record 23 of Set 13 | maragogi
# Processing Record 24 of Set 13 | bremerton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
# challenge objective
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Nizwa      OM  22.9333   57.5333     90.03        40
# 1           Hermanus      ZA -34.4187   19.2345     55.90        80
# 2    Bambous Virieux      MU -20.3428   57.7575     68.25        68
# 3          Cape Town      ZA -33.9258   18.4232     56.12        87
# 4      Mar Del Plata      AR -38.0023  -57.5575     53.62        87
# ..               ...     ...      ...       ...       ...       ...
# 574           Bratsk      RU  56.1325  101.6142     55.89        82
# 575         Pacifica      US  37.6138 -122.4869     98.26        77
# 576         Ucluelet      CA  48.9329 -125.5528     83.05        80
# 577         Maragogi      BR  -9.0122  -35.2225     73.90        74
# 578        Bremerton      US  47.5673 -122.6326     90.25        64
#
#      Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0            14        2.64          few clouds           0.00              0
# 1            22        6.96          few clouds           0.00              0
# 2            40       12.66          light rain           0.13              0
# 3             0        2.30           clear sky           0.00              0
# 4             0       10.36           clear sky           0.00              0
# ..          ...         ...                 ...            ...            ...
# 574         100        4.18     overcast clouds           0.00              0
# 575          40        4.00    scattered clouds           0.00              0
# 576          45        7.27    scattered clouds           0.00              0
# 577          78       10.47       broken clouds           0.00              0
# 578           1        6.91           clear sky           0.00              0
#
# [579 rows x 11 columns]

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 2   Bambous Virieux      MU -20.3428   57.7575     68.25        68
# 11          Bubaque      GW  11.2833  -15.8333     78.17        82
# 13           Dingle      PH  10.9995  122.6711     75.58        88
# 33           Dikson      RU  73.5069   80.5464     45.19       100
# 34           Narsaq      GL  60.9167  -46.0500     51.21        97
# 38             Nuuk      GL  64.1835  -51.7216     47.12        98
# 42      New Norfolk      AU -42.7826  147.0587     40.50        83
# 44      Provideniya      RU  64.3833 -173.3000     46.51        76
# 47             Lebu      CL -37.6167  -73.6500     49.98        91
# 58           Hobart      AU -42.8794  147.3294     40.86        89
#
#     Cloudiness  Wind Speed          Current Description  Rain (inches)  \
# 2           40       12.66                   light rain           0.13
# 11         100        8.84                moderate rain           1.68
# 13          67        4.45                   light rain           0.15
# 33         100       11.39                   light rain           0.13
# 34          97        3.78                moderate rain           1.01
# 38         100        9.24                   light rain           0.87
# 42         100        1.01                   light rain           0.18
# 44          90       13.42                moderate rain           1.64
# 47         100       24.40                   light rain           0.49
# 58          75       17.27  light intensity shower rain           0.13
#
#     Snow (inches)
# 2               0
# 11              0
# 13              0
# 33              0
# 34              0
# 38              0
# 42              0
# 44              0
# 47              0
# 58              0

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
